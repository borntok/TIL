# %%
from matplotlib import font_manager, rcParams
# !apt-get install fonts-nanum*         
rcParams['font.family'] = 'NanumGothicCoding'
rcParams['axes.unicode_minus'] = False
font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# fonts-nanum is already the newest version (20170925-1).
# fonts-nanum-coding is already the newest version (2.5-1).
# fonts-nanum-eco is already the newest version (1.000-6).
# fonts-nanum-extra is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
rawData = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/health_2016.csv')
rawData
# Out:
#      기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  ...  치아마모증유무  제3대구치(사랑니)이상   치석   데이터공개일자
# 0    2016   465969     1            8  ...      NaN           NaN  2.0  20171219
# 1    2016   565871     1           10  ...      NaN           NaN  NaN  20171219
# 2    2016   115718     2           11  ...      NaN           NaN  0.0  20171219
# 3    2016   767524     1            6  ...      NaN           NaN  NaN  20171219
# 4    2016   482178     2            9  ...      NaN           NaN  0.0  20171219
# ..    ...      ...   ...          ...  ...      ...           ...  ...       ...
# 995  2016   206725     2           12  ...      NaN           NaN  NaN  20171219
# 996  2016   339681     2           12  ...      NaN           NaN  NaN  20171219
# 997  2016   653494     2           11  ...      NaN           NaN  0.0  20171219
# 998  2016   190984     2           14  ...      NaN           NaN  NaN  20171219
# 999  2016   548105     1            6  ...      NaN           NaN  0.0  20171219
#
# ...

# %%
rawData.describe().T
# Out:
#                count          mean  ...          75%         max
# 기준년도          1000.0  2.016000e+03  ...      2016.00      2016.0
# 가입자일련번호       1000.0  5.097498e+05  ...    765463.00    999514.0
# 성별코드          1000.0  1.487000e+00  ...         2.00         2.0
# 연령대코드(5세단위)   1000.0  1.055700e+01  ...        12.00        18.0
# 시도코드          1000.0  3.315100e+01  ...        43.00        49.0
# 신장(5Cm단위)     1000.0  1.617000e+02  ...       170.00       185.0
# 체중(5Kg단위)     1000.0  6.278500e+01  ...        70.00       130.0
# 허리둘레          1000.0  8.103200e+01  ...        88.00       126.0
# 시력(좌)          999.0  9.800801e-01  ...         1.20         9.9
# 시력(우)          999.0  9.400400e-01  ...         1.20         9.9
# 청력(좌)          999.0  1.049049e+00  ...         1.00         2.0
# 청력(우)          999.0  1.032032e+00  ...         1.00         2.0
# 수축기혈압         1000.0  1.223810e+02  ...       130.00       180.0
# ...

# %%
rawData['흡연상태'].unique()
# Out:
# array([3., 1., 2.])

# %%
rawData['구강검진 수검여부'].unique()
# Out:
# array([1, 0])

# %%
rawData['성별코드'].unique()
# Out:
# array([1, 2])

# %%
sns.countplot(data=rawData, x='흡연상태')

# %%
sns.countplot(data=rawData, x='성별코드')

# %%
sns.countplot(data=rawData, x = '구강검진 수검여부')

# %%
rawData['연령대코드(5세단위)'].unique()
# Out:
# array([ 8, 10, 11,  6,  9, 14,  7, 15, 13,  5, 12, 16, 17, 18])

# %%
rawData['시도코드'].unique()
# Out:
# array([41, 11, 28, 42, 26, 29, 45, 43, 47, 48, 30, 27, 31, 44, 46, 36, 49])

# %%
sns.countplot(data=rawData, x='연령대코드(5세단위)')

# %%
sns.countplot(data=rawData, x='시도코드')

# %%
rawData.columns
# Out:
# Index(['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
#        '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진 수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상',
#        '치석', '데이터공개일자'],
#       dtype='object')

# %%
rawData['수축기혈압'].unique()
# Out:
# array([118., 134., 129., 137.,  92., 120., 138., 130., 140., 110., 119.,
#        114., 100., 141., 124., 112., 132., 105., 122., 128., 131., 125.,
#        108., 121., 126.,  91., 127., 117., 152., 109., 116., 136., 153.,
#        139., 150., 133., 106., 113., 170., 163., 145., 155., 104., 115.,
#        103., 135., 148., 154., 142., 123., 102.,  96.,  99., 107., 167.,
#         94.,  97., 101., 161., 160., 143.,  90., 111.,  88., 177., 144.,
#         98., 146., 156.,  95.,  89.,  93., 180., 165.])

# %%
rawData['총콜레스테롤'].unique()
# Out:
# array([194., 143., 203., 154., 239., 209., 193., 229., 166., 212., 206.,
#        170., 207., 276., 173., 176., 218., 153., 140., 254., 125., 223.,
#        200., 172., 294., 234., 146., 225., 168., 186., 163., 227., 120.,
#        175., 202., 211., 187., 162., 208., 185., 111., 189., 221., 270.,
#        161., 199., 195., 182., 240., 264., 157., 201., 214., 244., 222.,
#        192., 259., 238., 245., 178., 147., 190., 136., 171., 181., 133.,
#        188., 160., 265., 110., 177., 204., 165., 231., 249., 138., 228.,
#        256., 242., 151., 180., 250., 152., 141., 145., 253., 215., 213.,
#        306., 196., 205., 164., 169., 210., 261., 248., 241., 183., 219.,
#        262., 216., 260., 255., 174., 304., 109., 217., 232., 279., 124.,
#        184., 191., 150., 220., 103., 247., 246., 277., 197., 149., 275.,
#        159., 324., 101., 179., 252., 267., 310., 243., 278., 235., 230.,
#        132., 271., 167., 148., 251., 158., 226., 142., 236., 198., 130.,
# ...

# %%
sns.histplot(data=rawData, x='총콜레스테롤')

# %%
sns.histplot(data=rawData, x='트리글리세라이드', bins=100)

# %%
rawData[ rawData['트리글리세라이드'] > 1800]
# Out:
#      기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  ...  치아마모증유무  제3대구치(사랑니)이상   치석   데이터공개일자
# 942  2016   819247     1           12  ...      NaN           NaN  0.0  20171219
#
# [1 rows x 34 columns]

# %%
# 이상치 제거
tmp = rawData.drop(index=942)

# %%
sns.histplot(data=tmp, x='트리글리세라이드')

# %%
plt.hist(rawData['트리글리세라이드'], bins=50)
plt.xlim(21, 800)
plt.show()

# %%
sns.displot(data=rawData, x='총콜레스테롤', kde=True)

# %%
sns.scatterplot(data=tmp, x='총콜레스테롤', y='트리글리세라이드')

# %%
tmp[['총콜레스테롤', '트리글리세라이드']].corr()
# Out:
#             총콜레스테롤  트리글리세라이드
# 총콜레스테롤    1.000000  0.236431
# 트리글리세라이드  0.236431  1.000000

# %%
sns.regplot(data=tmp, x='총콜레스테롤', y='트리글리세라이드', line_kws={'color':'red'})

# %%
sns.rugplot(data=tmp, x='총콜레스테롤', height=1)

# %%
tmp['IDL콜레스테롤'] = tmp['총콜레스테롤'] - (tmp['HDL콜레스테롤'] + tmp['LDL콜레스테롤'])
tmp
# Out:
#      기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  ...  제3대구치(사랑니)이상   치석   데이터공개일자  IDL콜레스테롤
# 0    2016   465969     1            8  ...           NaN  2.0  20171219      20.0
# 1    2016   565871     1           10  ...           NaN  NaN  20171219      17.0
# 2    2016   115718     2           11  ...           NaN  0.0  20171219      11.0
# 3    2016   767524     1            6  ...           NaN  NaN  20171219       5.0
# 4    2016   482178     2            9  ...           NaN  0.0  20171219      30.0
# ..    ...      ...   ...          ...  ...           ...  ...       ...       ...
# 995  2016   206725     2           12  ...           NaN  NaN  20171219      21.0
# 996  2016   339681     2           12  ...           NaN  NaN  20171219      14.0
# 997  2016   653494     2           11  ...           NaN  0.0  20171219       9.0
# 998  2016   190984     2           14  ...           NaN  NaN  20171219      21.0
# ...

# %%
sns.jointplot(data=tmp, x='IDL콜레스테롤', y='트리글리세라이드')

# %%
sns.barplot(data=tmp, x='흡연상태', y='IDL콜레스테롤')

# %%
sns.barplot(data=tmp, x='흡연상태', y='총콜레스테롤')

# %%
sns.histplot(data=tmp, x='IDL콜레스테롤', hue='흡연상태')

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=tmp, x='IDL콜레스테롤', hue='성별코드', multiple='dodge') #hue:범주형이나 이산형

# %%
sns.boxplot(data=tmp, x='흡연상태', y='IDL콜레스테롤')

# %%
# 두 변수 모두 범주형
sns.countplot(data=tmp, x='성별코드', hue='흡연상태')

# %%
# 변수가 3개 이상인 경우

sns.barplot(data=tmp, x='흡연상태', y='IDL콜레스테롤', hue='성별코드')

# %%
sns.jointplot(data=tmp, x='IDL콜레스테롤', y='트리글리세라이드', hue='흡연상태')

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=tmp, x='IDL콜레스테롤', y='트리글리세라이드', hue='흡연상태', size='총콜레스테롤', sizes=(10,400))

# %%
plt.figure( figsize=(12, 5))

plt.subplot(2, 2, 1)
sns.countplot(data=tmp, x='흡연상태')

plt.subplot(2, 2, 2)
sns.barplot(data=tmp, x='흡연상태', y='IDL콜레스테롤')

plt.subplot(2, 2, 3)
sns.boxplot(data=tmp, x='흡연상태', y='IDL콜레스테롤')

plt.show()

# %%
plt.subplots(2, 2, figsize=(15, 5))
# Out:
# (<Figure size 1080x360 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6b066fd550>,
# ...
#        dtype=object))

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,5))
sns.countplot(data=tmp, x='흡연상태', ax=ax[0, 0])
sns.barplot(data=tmp, x='흡연상태', y='IDL콜레스테롤', ax=ax[0, 1])
sns.boxplot(data=tmp, x='흡연상태', y='IDL콜레스테롤', ax=ax[1,0])

# %%
# 색 지정
sns.palplot(sns.color_palette('hls', 20))

# %%
colors = sns.color_palette('rocket')
sns.countplot(data=tmp, x='연령대코드(5세단위)', palette=colors)

# %%
# 국가통계포털, 공공데이터포털, 통계청, 서울 열린데이터광장

# %%
tmp1 = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/200801_201012_주민등록인구기타현황(출생등록)_birth.csv', encoding='cp949')
tmp2 = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/201101_201312_주민등록인구기타현황(출생등록)_birth.csv', encoding='cp949')
tmp3 = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/201401_201612_주민등록인구기타현황(출생등록)_birth.csv', encoding='cp949')
tmp4 = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/201701_201912_주민등록인구기타현황(출생등록)_birth.csv', encoding='cp949')
tmp5 = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스/202001_202111_주민등록인구기타현황(출생등록)_birth.csv', encoding='cp949')

# %%
tmp1
# Out:
#                      행정구역  2008년01월_남자인구수  ...  2010년12월_여자인구수 2010년12월_계
# 0        전국  (1000000000)             NaN  ...             NaN     42,478
# 1     서울특별시  (1100000000)             NaN  ...             NaN      8,590
# 2     부산광역시  (2600000000)             NaN  ...             NaN      2,506
# 3     대구광역시  (2700000000)             NaN  ...             NaN      1,749
# 4     인천광역시  (2800000000)             NaN  ...             NaN      2,276
# 5     광주광역시  (2900000000)             NaN  ...             NaN      1,208
# 6     대전광역시  (3000000000)             NaN  ...             NaN      1,264
# 7     울산광역시  (3100000000)             NaN  ...             NaN      1,106
# 8       경기도  (4100000000)             NaN  ...             NaN     11,251
# 9       강원도  (4200000000)             NaN  ...             NaN      1,116
# 10     충청북도  (4300000000)             NaN  ...             NaN      1,293
# 11     충청남도  (4400000000)             NaN  ...             NaN      1,829
# ...

# %%
tmp = tmp1.iloc[:,0::3]
tmp
# Out:
#                      행정구역 2008년01월_계  ... 2010년11월_계 2010년12월_계
# 0        전국  (1000000000)     41,182  ...     43,912     42,478
# 1     서울특별시  (1100000000)      8,005  ...      8,717      8,590
# 2     부산광역시  (2600000000)      2,335  ...      2,620      2,506
# 3     대구광역시  (2700000000)      1,816  ...      1,961      1,749
# 4     인천광역시  (2800000000)      2,169  ...      2,384      2,276
# 5     광주광역시  (2900000000)      1,280  ...      1,330      1,208
# 6     대전광역시  (3000000000)      1,361  ...      1,285      1,264
# 7     울산광역시  (3100000000)        959  ...      1,047      1,106
# 8       경기도  (4100000000)     10,481  ...     11,501     11,251
# 9       강원도  (4200000000)      1,169  ...      1,113      1,116
# 10     충청북도  (4300000000)      1,339  ...      1,432      1,293
# 11     충청남도  (4400000000)      1,808  ...      1,863      1,829
# 12     전라북도  (4500000000)      1,497  ...      1,443      1,346
# 13     전라남도  (4600000000)      1,578  ...      1,530      1,453
# ...

# %%
tmp['행정구역']
# Out:
# 0          전국  (1000000000)
# 1       서울특별시  (1100000000)
# 2       부산광역시  (2600000000)
# 3       대구광역시  (2700000000)
# 4       인천광역시  (2800000000)
# 5       광주광역시  (2900000000)
# 6       대전광역시  (3000000000)
# 7       울산광역시  (3100000000)
# 8         경기도  (4100000000)
# 9         강원도  (4200000000)
# 10       충청북도  (4300000000)
# 11       충청남도  (4400000000)
# 12       전라북도  (4500000000)
# 13       전라남도  (4600000000)
# 14       경상북도  (4700000000)
# 15       경상남도  (4800000000)
# 16    제주특별자치도  (5000000000)
# Name: 행정구역, dtype: object

# %%
tmp.drop(0, inplace=True)

# %%
tmp
# Out:
#                      행정구역 2008년01월_계  ... 2010년11월_계 2010년12월_계
# 1     서울특별시  (1100000000)      8,005  ...      8,717      8,590
# 2     부산광역시  (2600000000)      2,335  ...      2,620      2,506
# 3     대구광역시  (2700000000)      1,816  ...      1,961      1,749
# 4     인천광역시  (2800000000)      2,169  ...      2,384      2,276
# 5     광주광역시  (2900000000)      1,280  ...      1,330      1,208
# 6     대전광역시  (3000000000)      1,361  ...      1,285      1,264
# 7     울산광역시  (3100000000)        959  ...      1,047      1,106
# 8       경기도  (4100000000)     10,481  ...     11,501     11,251
# 9       강원도  (4200000000)      1,169  ...      1,113      1,116
# 10     충청북도  (4300000000)      1,339  ...      1,432      1,293
# 11     충청남도  (4400000000)      1,808  ...      1,863      1,829
# 12     전라북도  (4500000000)      1,497  ...      1,443      1,346
# 13     전라남도  (4600000000)      1,578  ...      1,530      1,453
# 14     경상북도  (4700000000)      2,094  ...      2,149      2,123
# ...

# %%
tmp.columns
# Out:
# Index(['행정구역', '2008년01월_계', '2008년02월_계', '2008년03월_계', '2008년04월_계',
#        '2008년05월_계', '2008년06월_계', '2008년07월_계', '2008년08월_계', '2008년09월_계',
#        '2008년10월_계', '2008년11월_계', '2008년12월_계', '2009년01월_계', '2009년02월_계',
#        '2009년03월_계', '2009년04월_계', '2009년05월_계', '2009년06월_계', '2009년07월_계',
#        '2009년08월_계', '2009년09월_계', '2009년10월_계', '2009년11월_계', '2009년12월_계',
#        '2010년01월_계', '2010년02월_계', '2010년03월_계', '2010년04월_계', '2010년05월_계',
#        '2010년06월_계', '2010년07월_계', '2010년08월_계', '2010년09월_계', '2010년10월_계',
#        '2010년11월_계', '2010년12월_계'],
#       dtype='object')

# %%
tmp.columns = ['행정구역', '2008-01', '2008-02', '2008-03', '2008-04',
       '2008-05', '2008-06', '2008-07', '2008-08', '2008-09',
       '2008-10', '2008-11', '2008-12', '2009-01', '2009-02',
       '2009-03', '2009-04', '2009-05', '2009-06', '2009-07',
       '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
       '2010-01', '2010-02', '2010-03', '2010-04', '2010-05',
       '2010-06', '2010-07', '2010-08', '2010-09', '2010-10',
       '2010-11', '2010-12']

# %%
tmp
# Out:
#                      행정구역 2008-01 2008-02  ... 2010-10 2010-11 2010-12
# 1     서울특별시  (1100000000)   8,005   8,618  ...   8,430   8,717   8,590
# 2     부산광역시  (2600000000)   2,335   2,296  ...   2,519   2,620   2,506
# 3     대구광역시  (2700000000)   1,816   1,870  ...   1,893   1,961   1,749
# 4     인천광역시  (2800000000)   2,169   2,215  ...   2,250   2,384   2,276
# 5     광주광역시  (2900000000)   1,280   1,248  ...   1,254   1,330   1,208
# 6     대전광역시  (3000000000)   1,361   1,327  ...   1,314   1,285   1,264
# 7     울산광역시  (3100000000)     959     999  ...   1,076   1,047   1,106
# 8       경기도  (4100000000)  10,481  10,708  ...  11,091  11,501  11,251
# 9       강원도  (4200000000)   1,169   1,133  ...   1,067   1,113   1,116
# 10     충청북도  (4300000000)   1,339   1,229  ...   1,272   1,432   1,293
# 11     충청남도  (4400000000)   1,808   1,718  ...   1,858   1,863   1,829
# 12     전라북도  (4500000000)   1,497   1,371  ...   1,427   1,443   1,346
# ...

# %%
for i in tmp.columns :
  tmp[i] = tmp[i].str.replace(',','')

# %%
tmp
# Out:
#                      행정구역 2008-01 2008-02  ... 2010-10 2010-11 2010-12
# 1     서울특별시  (1100000000)    8005    8618  ...    8430    8717    8590
# 2     부산광역시  (2600000000)    2335    2296  ...    2519    2620    2506
# 3     대구광역시  (2700000000)    1816    1870  ...    1893    1961    1749
# 4     인천광역시  (2800000000)    2169    2215  ...    2250    2384    2276
# 5     광주광역시  (2900000000)    1280    1248  ...    1254    1330    1208
# 6     대전광역시  (3000000000)    1361    1327  ...    1314    1285    1264
# 7     울산광역시  (3100000000)     959     999  ...    1076    1047    1106
# 8       경기도  (4100000000)   10481   10708  ...   11091   11501   11251
# 9       강원도  (4200000000)    1169    1133  ...    1067    1113    1116
# 10     충청북도  (4300000000)    1339    1229  ...    1272    1432    1293
# 11     충청남도  (4400000000)    1808    1718  ...    1858    1863    1829
# 12     전라북도  (4500000000)    1497    1371  ...    1427    1443    1346
# ...

# %%
tmp["2008-01"] = pd.to_numeric(tmp["2008-01"])

# %%
tmpp = tmp.drop(['행정구역'], axis=1)
tmpp.columns
# Out:
# Index(['2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
#        '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12'],
#       dtype='object')

# %%
for i in tmpp.columns :
  tmpp[i] = pd.to_numeric(tmpp[i])

# %%
tmpp.insert(0, '행정구역', tmp['행정구역'])

# %%
tmpp
# Out:
#                      행정구역  2008-01  2008-02  ...  2010-10  2010-11  2010-12
# 1     서울특별시  (1100000000)     8005     8618  ...     8430     8717     8590
# 2     부산광역시  (2600000000)     2335     2296  ...     2519     2620     2506
# 3     대구광역시  (2700000000)     1816     1870  ...     1893     1961     1749
# 4     인천광역시  (2800000000)     2169     2215  ...     2250     2384     2276
# 5     광주광역시  (2900000000)     1280     1248  ...     1254     1330     1208
# 6     대전광역시  (3000000000)     1361     1327  ...     1314     1285     1264
# 7     울산광역시  (3100000000)      959      999  ...     1076     1047     1106
# 8       경기도  (4100000000)    10481    10708  ...    11091    11501    11251
# 9       강원도  (4200000000)     1169     1133  ...     1067     1113     1116
# 10     충청북도  (4300000000)     1339     1229  ...     1272     1432     1293
# 11     충청남도  (4400000000)     1808     1718  ...     1858     1863     1829
# ...
