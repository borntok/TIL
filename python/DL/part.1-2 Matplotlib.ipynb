# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.arange(10)
plt.plot(data)
plt.show()

# %% [markdown]
# ### figure&subplot

# %%
fig = plt.figure()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
plt.show()

# %% [markdown]
# ### plt로 그래프 그리기

# %%
fig = plt.figure()
ax = fig.add_subplot()

data = np.array([1, 2, 3])

plt.plot(data)
plt.show()

# %%
fig = plt.figure()

x = [1, 2, 3]
y1 = [1, 2, 3]
y2 = [3, 2, 1]

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.plot(x, y1)
ax2.plot(x, y2)

plt.show()

# %% [markdown]
# ### plot 종류별 사용법

# %% [markdown]
# #### bar plot
# - bar plot은 ax.bar와 같이 사용하며 다음과 같은 인자를 받습니다.
#  - x: x축에 사용될 값
#  - height: y축에 사용될 값
#  - width:각 bar의 width
#  - bottom: y축의 base값
#  - align: 정렬(center or edge)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.bar([0,1,2,3,4], [3,2,5,4,6], width=0.5)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.bar([0,1,2,3,4], [3,2,5,4,6], bottom=2)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.bar([0,1,2,3,4], [3,2,5,4,6], align='edge')
plt.show()

# %% [markdown]
# #### histogram
# - histogram은 data의 분포를 나타낼 때 사용하며, 주로 다음과 같은 인자를 사용
#  - x: 입력 date
#  - bins: histogram을 나타낼 x축의 구간(정수 입력시 구간의 개수, list와 같은 sequence 입력시 sequence 값이 구간으로 설정됨)
#  - range: x축 범위(x.min, x.max)로 표현
#  - density: 확률 분포로 나타낼 것인지 여부

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.hist(np.random.randn(1000))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.hist(np.random.randn(1000), bins=50)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.hist(np.random.randn(1000), np.linspace(-3, 3, num=40))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.hist(np.random.randn(1000), bins=40, range=(-2,2))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.hist(np.random.randn(1000), bins=50, range=(-3,3), density=True)
plt.show()

# %% [markdown]
# #### line plot
# - 가장 기본적인 plot으로 x, y data의 관계를 선으로 표시해주는 graph
#  - x: x data
#  - y: y data
#  - fmt: 색상, 마커, 선 스타일 등 설정

# %%
pip install -U finance-datareader -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import FinanceDataReader as fdr

# %%
df = fdr.DataReader('005930')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1997-11-14    798    798    759    776    304930       NaN
# 1997-11-15    795    798    786    795    244310  0.024485
# 1997-11-17    795    811    750    754    230630 -0.051572
# 1997-11-18    732    766    716    756    367558  0.002653
# 1997-11-19    755    773    732    768    365690  0.015873
# ...           ...    ...    ...    ...       ...       ...
# 2021-12-13  77200  78300  76500  76800  15038750 -0.001300
# 2021-12-14  76500  77200  76200  77000  10976660  0.002604
# 2021-12-15  76400  77600  76300  77600   9584939  0.007792
# 2021-12-16  78500  78500  77400  77800  11996128  0.002577
# 2021-12-17  76800  78000  76800  78000  11802494  0.002571
#
# [6000 rows x 6 columns]

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot()
ax.plot(df['Close'][-200:], 'y^--')
plt.show()

# %% [markdown]
# #### scatter plot
# - scatter plot은 line plot과 유사하게 x, y data의 관계를 점으로 표현
# - scatter plot은 data 간의 상관관계를 파악할 때 주로 사용
# - Iris dataset을 이용하여 scatter plot 그려보기

# %%
import pandas as pd

# %%
iris_df = pd.read_csv(r'C:\Users\LGE1\TIL\python\DL\Iris.csv')
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x = iris_df['PetalLengthCm'],
           y = iris_df['PetalWidthCm'])
plt.show()

# %% [markdown]
# ### 한 subplot에 여러개 graph 그리기

# %%
fig = plt.figure()

ax = fig.add_subplot()
ax.plot([1, 1.5, 2])
ax.plot([1, 2, 3])
ax.plot([1, 2.5, 4])
plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot()
ax.plot([1, 2, 3], [1, 2, 3])
ax.bar([1, 2 ,3 ], [1, 2, 3], color='gray')
plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot()

for species in iris_df['Species'].unique():
    iris_sub = iris_df[iris_df['Species']==species]
    ax.scatter(x=iris_sub['PetalLengthCm'],
               y=iris_sub['PetalWidthCm'])
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(10,5))
axes[0, 1].plot([1, 2, 3])
axes[1, 2].plot([3, 2, 1])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,5))

axes[0,0].hist(np.random.randn(200), bins=20)
axes[0,1].bar(np.arange(10), np.random.randn(10)*10+10)
axes[1,0].scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))
axes[1,1].plot(np.random.randn(50).cumsum()*5+20)

plt.show()

# %%
# 축 눈금 공유
np.random.seed(1111)
fig, axes = plt.subplots(2, 2, figsize=(10,5), sharey=True)

axes[0,0].hist(np.random.randn(200), bins=20)
axes[0,1].bar(np.arange(10), np.random.randn(10)*10+10)
axes[1,0].scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))
axes[1,1].plot(np.random.randn(50).cumsum()*5+20)

plt.show()

# %%
# subplot 간격 조정

fig, axes = plt.subplots(2, 2, figsize=(10,5), sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500), bins=50)
        
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# ### 색상 지정

# %%
np.random.seed(1111)
fig, axes = plt.subplots(2, 2, figsize=(10,5), sharey=True)

axes[0,0].hist(np.random.randn(200), bins=20, color='m')
axes[0,1].bar(np.arange(10), np.random.randn(10)*10+10, color='seagreen')
axes[1,0].scatter(np.arange(30), np.arange(30)+3*np.random.randn(30), color='#0000ff')
axes[1,1].plot(np.random.randn(50).cumsum()*5+20, color='brown')

plt.show()

# %% [markdown]
# ### label 지정하기

# %%
fig = plt.figure()

ax = fig.add_subplot()

for species in iris_df['Species'].unique():
    iris_sub = iris_df[iris_df['Species']==species]
    ax.scatter(x=iris_sub['PetalLengthCm'],
               y=iris_sub['PetalWidthCm'],
               label=species)
plt.legend()
plt.show()

# %% [markdown]
# ### 제목, 축 이름, 눈금 설정

# %%
fig = plt.figure()

ax = fig.add_subplot()

for species in iris_df['Species'].unique():
    iris_sub = iris_df[iris_df['Species']==species]
    ax.scatter(x=iris_sub['PetalLengthCm'],
               y=iris_sub['PetalWidthCm'],
               label=species)

ax.set_title('Iris')
xticks = np.arange(1, 7.5, 0.5)
ax.set_xticks = xticks
ax.set_xlabel('PetalLengthCm')
ax.set_ylabel('PetalWidthCm')

plt.legend()
plt.show()

# %% [markdown]
# ### Image data visualization
# - image data는 plt.imshow()를 이용하여 출력 가능
#  - X: image data, gray scale의 경우 2차원 RGB, RGBA의 경우는 3차원의 데이터가 필요함. data의 shape은 (height, width, channel) 순
#  - cmap: colormap

# %%
from PIL import Image

# %%
image = Image.open(r'C:\Users\LGE1\TIL\python\DL\cat_image.jpeg')
fig = plt.figure()
ax = fig.add_subplot()
ax.imshow(image)
plt.show()
